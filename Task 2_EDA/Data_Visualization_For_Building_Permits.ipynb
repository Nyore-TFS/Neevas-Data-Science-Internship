# %% [markdown]
# # INTRODUCTION.

# %% [markdown]
# ### Based on the dataset for the city of Rockford, Illinois which I have cleaned, I will be creating some visaulizations in order for us to have more insights about the Building Permits.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator

# %%
df = pd.read_csv("cleaned data.csv")
df
# Out:
#       Date Issued   Month                     Permit Type       Permit No  \
# 0      2022-08-01  Aug-22              Mechanical Permits    MECH20222077
# 1      2022-08-01  Aug-22          Single Family Dwelling     SFD20222251
# 2      2022-08-01  Aug-22  Multifamily/Commercial Permits  MULCOM20221669
# 3      2022-08-01  Aug-22              Electrical Permits   ELECT20221704
# 4      2022-08-01  Aug-22                Plumbing Permits    PLUM20222072
# ...           ...     ...                             ...             ...
# 19652  2024-08-30  Aug-24          Single Family Dwelling     SFD20242986
# 19653  2024-08-30  Aug-24          Single Family Dwelling     SFD20242805
# 19654  2024-08-30  Aug-24          Single Family Dwelling     SFD20243074
# 19655  2024-08-30  Aug-24                    Fire Permits    FIRE20241074
# 19656  2024-08-31  Aug-24          Single Family Dwelling     SFD20242610
#
#        Work Type Property's Address            PIN  \
# ...

# %%
df.shape
# Out:
# (19657, 11)

# %%
data = df.copy()
data.shape
# Out:
# (19657, 11)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19657 entries, 0 to 19656
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Date Issued             19657 non-null  object
#  1   Month                   19657 non-null  object
#  2   Permit Type             19657 non-null  object
#  3   Permit No               19657 non-null  object
#  4   Work Type               19657 non-null  object
#  5   Property's Address      19645 non-null  object
#  6   PIN                     17509 non-null  object
#  7   AP Name                 19657 non-null  object
#  8   Contractor's Full Name  19636 non-null  object
#  9   Valuation($)            19657 non-null  float64
#  10  Description             19657 non-null  object
# dtypes: float64(1), object(10)
# memory usage: 1.6+ MB

# %%
data['Date Issued'] = pd.to_datetime(data['Date Issued']).dt.normalize()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19657 entries, 0 to 19656
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Date Issued             19657 non-null  datetime64[ns]
#  1   Month                   19657 non-null  object
#  2   Permit Type             19657 non-null  object
#  3   Permit No               19657 non-null  object
#  4   Work Type               19657 non-null  object
#  5   Property's Address      19645 non-null  object
#  6   PIN                     17509 non-null  object
#  7   AP Name                 19657 non-null  object
#  8   Contractor's Full Name  19636 non-null  object
#  9   Valuation($)            19657 non-null  float64
#  10  Description             19657 non-null  object
# dtypes: datetime64[ns](1), float64(1), object(9)
# memory usage: 1.6+ MB

# %% [markdown]
# #### Create a plot fo the "Month" column to see how many permits were given in each month.

# %%
sns.histplot(x=data['Month'])
plt.xticks(rotation=90)
plt.gca().yaxis.set_major_locator(MultipleLocator(100))
plt.show()

# %% [markdown]
# #### Create a plot to know the number of Permit types that were granted

# %%
order = data['Permit Type'].value_counts().index[::1]
sns.countplot(x=data['Permit Type'], order=order)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### Determine the total number of Contractor's that were contracted for jobs in the city of Rockford.

# %%
contractor_counts = data["Contractor's Full Name"].value_counts()
print("Total Contractor's in this dataset:" )
print(len(contractor_counts))
print("*********************")
print(contractor_counts)
# Out:
# Total Contractor's in this dataset:
# 3845
# *********************
# Contractor's Full Name
# Gutierrez Maribel                 728
# Sunrun Installation Services      702
# Pearson Plumbing & Heating        634
# Helm Electric                     353
# Vanbuskirk Mark                   314
#                                  ...
# Molina Vanessa                      1
# Rezek Matthew                       1
# American Hoist And Manlift Inc      1
# Paul Clifford                       1
# Infante Myrka                       1
# Name: count, Length: 3845, dtype: int64

# %% [markdown]
# #### Based on the observations from the dataset, we would create visualizations in groups for the the Contractor's that were contracted.

# %%
min_freq = 200
contractor_counts = data["Contractor's Full Name"].value_counts()[
    (data["Contractor's Full Name"].value_counts()> min_freq)]
print("Total Contractor's in this category is:" )
print(len(contractor_counts))
plt.figure(figsize=(10, 6))
contractor_counts.plot(kind='bar')
plt.title("Contractor's Names with Frequency Greater than 200")
plt.xlabel("Contracto's Name")
plt.ylabel('Frequency')
plt.xticks(rotation=90)
plt.show()
# Out:
# Total Contractor's in this category is:
# 13

# %%
min_freq = 51
max_freq = 200
contractor_counts = data["Contractor's Full Name"].value_counts()[
    (data["Contractor's Full Name"].value_counts()>= min_freq) &
    (data["Contractor's Full Name"].value_counts() <= max_freq)]
print("Total Contractor's in this category is:" )
print(len(contractor_counts))
plt.figure(figsize=(10, 6))
contractor_counts.plot(kind='bar')
plt.title("Contractor's Names with Frequency from 51 to 200")
plt.xlabel("Contracto's Name")
plt.ylabel('Frequency')
plt.xticks(rotation=90)
plt.show()
# Out:
# Total Contractor's in this category is:
# 47

# %%
min_freq = 31
max_freq = 50
contractor_counts = data["Contractor's Full Name"].value_counts()[
    (data["Contractor's Full Name"].value_counts()>= min_freq) &
    (data["Contractor's Full Name"].value_counts() <= max_freq)
    ]
print("Total Contractor's in this category is:" )
print(len(contractor_counts))
plt.figure(figsize=(10, 6))
contractor_counts.plot(kind='bar')
plt.title(f"Contractor's Names with Frequency from {min_freq} to {max_freq}")
plt.xlabel("Contracto's Name")
plt.ylabel('Frequency')
plt.xticks(rotation=90)
plt.show()
# Out:
# Total Contractor's in this category is:
# 26

# %%
min_freq = 21
max_freq = 30
contractor_counts = data["Contractor's Full Name"].value_counts()[
    (data["Contractor's Full Name"].value_counts()>= min_freq) &
    (data["Contractor's Full Name"].value_counts() <= max_freq)
    ]
print("Total Contractor's in this category is:" )
print(len(contractor_counts))
plt.figure(figsize=(10, 6))
contractor_counts.plot(kind='bar')
plt.title(f"Contractor's Names with Frequency between {min_freq} and {max_freq}")
plt.xlabel("Contracto's Name")
plt.ylabel('Frequency')
plt.xticks(rotation=90)
plt.show()
# Out:
# Total Contractor's in this category is:
# 44

# %%
min_freq = 15
max_freq = 20
contractor_counts = data["Contractor's Full Name"].value_counts()[
    (data["Contractor's Full Name"].value_counts()>= min_freq) &
    (data["Contractor's Full Name"].value_counts() <= max_freq)
    ]
print("Total Contractor's in this category is:" )
print(len(contractor_counts))
plt.figure(figsize=(10, 6))
contractor_counts.plot(kind='bar')
plt.title(f"Contractor's Names with Frequency between {min_freq} and {max_freq}")
plt.xlabel("Contracto's Name")
plt.ylabel('Frequency')
plt.xticks(rotation=90)
plt.show()
# Out:
# Total Contractor's in this category is:
# 37

# %%
min_freq = 11
max_freq = 14
contractor_counts = data["Contractor's Full Name"].value_counts()[
    (data["Contractor's Full Name"].value_counts()>= min_freq) &
    (data["Contractor's Full Name"].value_counts() <= max_freq)
    ]
print("Total Contractor's in this category is:" )
print(len(contractor_counts))
plt.figure(figsize=(10, 6))
contractor_counts.plot(kind='bar')
plt.title(f"Contractor's Names with Frequency between {min_freq} and {max_freq}")
plt.xlabel("Contracto's Name")
plt.ylabel('Frequency')
plt.xticks(rotation=90)
plt.show()
# Out:
# Total Contractor's in this category is:
# 59

# %%
min_freq = 5
max_freq = 10
contractor_counts = data["Contractor's Full Name"].value_counts()[
    (data["Contractor's Full Name"].value_counts()>= min_freq) &
    (data["Contractor's Full Name"].value_counts() <= max_freq)
    ]
print(contractor_counts)
# Out:
# Contractor's Full Name
# Johnson James                      10
# Mendes Maintenance & Remodeling    10
# Belknap Paul                       10
# Wight Sr Ron                       10
# Morse Electric Inc. Melissa        10
#                                    ..
# Savalla Joseph                      5
# Lindsey Paul                        5
# Kierzkowski  Greg                   5
# Held Dan                            5
# Granados Miguel                     5
# Name: count, Length: 275, dtype: int64

# %%
min_freq = 1
max_freq = 4
contractor_counts = data["Contractor's Full Name"].value_counts()[
    (data["Contractor's Full Name"].value_counts()>= min_freq) &
    (data["Contractor's Full Name"].value_counts() <= max_freq)
    ]
print(contractor_counts)
# Out:
# Contractor's Full Name
# Ramos Yajaira                     4
# Ms Painting And Remodeling Llc    4
# Ellen Franko                      4
# Sancha Daniel                     4
# Zalewski Maciej                   4
#                                  ..
# Molina Vanessa                    1
# Rezek Matthew                     1
# American Hoist And Manlift Inc    1
# Paul Clifford                     1
# Infante Myrka                     1
# Name: count, Length: 3344, dtype: int64

# %%
data['Valuation($)'] = data['Valuation($)'].astype(int)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19657 entries, 0 to 19656
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Date Issued             19657 non-null  datetime64[ns]
#  1   Month                   19657 non-null  object
#  2   Permit Type             19657 non-null  object
#  3   Permit No               19657 non-null  object
#  4   Work Type               19657 non-null  object
#  5   Property's Address      19645 non-null  object
#  6   PIN                     17509 non-null  object
#  7   AP Name                 19657 non-null  object
#  8   Contractor's Full Name  19636 non-null  object
#  9   Valuation($)            19657 non-null  int32
#  10  Description             19657 non-null  object
# dtypes: datetime64[ns](1), int32(1), object(9)
# memory usage: 1.6+ MB

# %% [markdown]
# #### Determine the total valution gotten by the top contracted contractors.

# %%
top_contractors = data["Contractor's Full Name"].value_counts().nlargest(13)
top_contractors_data = df[data["Contractor's Full Name"].isin(
    top_contractors.index)]
valuation_sum = top_contractors_data.groupby(
    "Contractor's Full Name")["Valuation($)"].sum().reset_index()
valuation_sum = valuation_sum.sort_values("Valuation($)",
                                          ascending=False)

plt.figure(figsize=(10, 8))
sns.barplot(x="Contractor's Full Name", y="Valuation($)",
            data = valuation_sum)
plt.title("Top Contractor's by Frequeuncy and Project Valuaiton")
plt.xlabel("Contractor's Name")
plt.ylabel('Valuation($)')
plt.xticks(rotation=90)
plt.yticks(rotation=45)
plt.ticklabel_format(axis='y', style='plain', useOffset=False)
plt.show()

# %% [markdown]
# #### Determine the total amount paid to contractors monthly form August 2022 to August 2024 which is the duration covered by the dataset.

# %%
valuation_per_month = data.groupby(
    "Month")["Valuation($)"].sum().reset_index()
valuation_per_month = valuation_per_month.sort_values("Valuation($)", 
                                                      ascending=False)

plt.figure(figsize=(10, 8))
sns.barplot(x="Month", y="Valuation($)",
            data = valuation_per_month)
plt.title("Project Valuation per Month")
plt.xlabel("Month's")
plt.ylabel('Valuation($)')
plt.xticks(rotation=90)
plt.yticks(rotation=45)
plt.ticklabel_format(axis='y', style='plain', useOffset=False)
plt.show()

# %% [markdown]
# #### Determine the total amount spent on project for the years captured in dataset

# %%
# Extract year from the date
data['Year'] = pd.to_datetime(data['Date Issued']).dt.year

# Group by year and sum valuations
yearly_valuation = data.groupby('Year')['Valuation($)'].sum().reset_index()

# Create a bar plot
plt.figure(figsize=(8, 8))
sns.barplot(x='Year', y='Valuation($)', data=yearly_valuation)

# Add titles and labels
plt.title('Yearly Project Valuation (2022-2024)')
plt.xlabel('Year')
plt.ylabel('Total Valuation')
plt.yticks(rotation=45)
plt.ticklabel_format(axis='y', style='plain', useOffset=False)
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# #### Viaualization for year 2023 to see which quarter of the year in which more money was spent on contruction works.

# %%
data['Year_2023'] = pd.to_datetime(data['Date Issued'])

# Filter for the year 2023
data_2023 = data[data['Year_2023'].dt.year == 2023]

# Create a new column for quarters
data_2023['Quarter'] = data_2023['Year_2023'].apply(
    lambda x: 'Jan-Jun' if x.month <= 6 else 'Jul-Dec'
    )

# Group by quarters and sum valuations
quarterly_valuation = data_2023.groupby('Quarter')['Valuation($)'].sum().reset_index()


plt.figure(figsize=(8, 6))
sns.barplot(x='Quarter', y='Valuation($)', data=quarterly_valuation)


plt.title('2023 Project Valuation by Quarter')
plt.xlabel('Quarter')
plt.ylabel('Total Valuation')
plt.yticks(rotation=45)
plt.ticklabel_format(axis='y', style='plain', useOffset=False)
plt.tight_layout()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_238212\3701286218.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_2023['Quarter'] = data_2023['Year_2023'].apply(

# %% [markdown]
# #### Visaualizing the total valuation based on permit type

# %%
permit = data.groupby(
    "Permit Type")["Valuation($)"].sum().reset_index()

sns.lineplot(x='Permit Type', y='Valuation($)', data=permit)
plt.xlabel('Permit Type')
plt.xticks(rotation=90)
plt.ylabel('Valuation($)')
plt.title('Line Chart of Valuation by Permit Type')
plt.ticklabel_format(axis='y', style='plain', useOffset=False)
plt.show()
